# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from pylab import rcParams
rcParams['figure.figsize'] = 10, 5

# %%
data = pd.read_csv('data/Cleaned_StateData_2.csv')
data.head()
# Out:
#    Year        ID  State_Code  County       State  FIPS_Code_State  FYEndDate  \
# 0  2016  10000000           1       0     ALABAMA                1        930
# 1  2016  20000000           2       0      ALASKA                2        630
# 2  2016  30000000           3       0     ARIZONA                4        630
# 3  2016  40000000           4       0    ARKANSAS                5        630
# 4  2016  50000000           5       0  CALIFORNIA                6        630
#
#    Population  Total_Revenue  Total_Rev_Own_Sources           ...             \
# 0     4858979       30172490               20650521           ...
# 1      738432        8060170                5206968           ...
# 2     6828065       38241052               23700590           ...
# 3     2978204       21431620               14000079           ...
# 4    39144818      322332307              227996024           ...
#
#    Emp_Retire_Sec_Mortgages  Emp_Retire_Sec_Misc_Inv  Emp_Retire_Sec_Oth_Nong  \
# ...

# %%
data.keys().tolist()
# Out:
# ['Year',
#  'ID',
#  'State_Code',
#  'County',
#  'State',
#  'FIPS_Code_State',
#  'FYEndDate',
#  'Population',
#  'Total_Revenue',
#  'Total_Rev_Own_Sources',
#  'General_Revenue',
#  'Gen_Rev_Own_Sources',
#  'Total_Taxes',
#  'Property_Tax',
#  'Tot_Sales___Gr_Rec_Tax',
#  'Total_Gen_Sales_Tax',
#  'Total_Select_Sales_Tax',
#  'Alcoholic_Beverage_Tax',
#  'Amusement_Tax',
#  'Insurance_Premium_Tax',
#  'Motor_Fuels_Tax',
#  'Pari_mutuels_Tax',
#  'Public_Utility_Tax',
#  'Tobacco_Tax',
#  'Other_Select_Sales_Tax',
#  'Total_License_Taxes',
#  'Alcoholic_Beverage_Lic',
#  'Amusement_License',
#  'Corporation_License',
#  'Hunting___Fishing_License',
#  'Motor_Vehicle_License',
#  'Motor_Veh_Oper_License',
#  'Motor_Vehicle_License_Total',
#  'Public_Utility_License',
#  'Occup_and_Bus_Lic_NEC',
#  'Other_License_Taxes',
#  'Total_Income_Taxes',
#  'Individual_Income_Tax',
#  'Corp_Net_Income_Tax',
#  'Death_and_Gift_Tax',
#  'Docum_and_Stock_Tr_Tax',
#  'Severance_Tax',
# ...

# %%
import sklearn.preprocessing

# %%
data.head()
# Out:
#    Year        ID  State_Code  County       State  FIPS_Code_State  FYEndDate  \
# 0  2016  10000000           1       0     ALABAMA                1        930
# 1  2016  20000000           2       0      ALASKA                2        630
# 2  2016  30000000           3       0     ARIZONA                4        630
# 3  2016  40000000           4       0    ARKANSAS                5        630
# 4  2016  50000000           5       0  CALIFORNIA                6        630
#
#    Population  Total_Revenue  Total_Rev_Own_Sources           ...             \
# 0     4858979       30172490               20650521           ...
# 1      738432        8060170                5206968           ...
# 2     6828065       38241052               23700590           ...
# 3     2978204       21431620               14000079           ...
# 4    39144818      322332307              227996024           ...
#
#    Emp_Retire_Sec_Mortgages  Emp_Retire_Sec_Misc_Inv  Emp_Retire_Sec_Oth_Nong  \
# ...

# %%
data[['Population':]]
# Out:
#   File "<ipython-input-17-be08d7c7814e>", line 1
#     data[['Population':]]
#                       ^
# SyntaxError: invalid syntax

# %%
sklearn.preprocessing.scale(data, axis=0)
# sklearn.preprocessing.scale(data_normalized[numeric_features], axis=0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-f6805ad42942> in <module>
# ----> 1 sklearn.preprocessing.scale(data, axis=0)
#       2 # sklearn.preprocessing.scale(data_normalized[numeric_features], axis=0)
#
# AttributeError: module 'sklearn' has no attribute 'preprocessing'
